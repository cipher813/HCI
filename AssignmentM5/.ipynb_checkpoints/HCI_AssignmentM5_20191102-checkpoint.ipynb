# %%
import pandas as pd

# %%
questions = [
    "Age",
    "Gender",
    "Profession",
    "Primary for work",
    "If other",
    "Primary for Personal",
    "If Other",
    "Favorite",
    "Why favorite",
    "Proficiency",
    "Frequency",
    "Frequency Shared Calendar",
    "Design",
    "Speed",
    "Shared Calendar",
    "Ease",
    "Learnability",
    "Concerns",
    "Comments",
]

# %%
df = pd.read_csv("survey.csv").set_index("response").T
df['questions'] = questions
df = df.T
df
# Out:
#                 Q1      Q2                      Q3                  Q4  \
# response
# 1          30 - 39    Male      Software Developer  Microsoft Outlooke
# 2          18 - 29    Male          Data Scientist       Google GSuite
# 3          18 - 29    Male       Software Engineer  Microsoft Outlooke
# 4          18 - 29    Male         Product manager       Google GSuite
# 5          18 - 29    Male                Engineer       Google GSuite
# 6          18 - 29    Male             Oil and Gas  Microsoft Outlooke
# 7          30 - 39  Female                 IT Lead  Microsoft Outlooke
# 8          30 - 39    Male                      IT       Google GSuite
# 9          30 - 39    Male       Software Engineer  Microsoft Outlooke
# 10         18 - 29  Female       technical analyst       Google GSuite
# 11         18 - 29    Male     Student/Free-lancer               Other
# 12         40 - 49    Male           data engineer  Microsoft Outlooke
# ...

# %%
df['Q3'] = df['Q3'].apply(lambda x: x.title())
df.groupby("Q3").agg({"Q1":"count"})
# Out:
#                         Q1
# Q3
# Bookkeeper               1
# Data Engineer            1
# Data Scientist           1
# Engineer                 1
# It                       1
# It Lead                  1
# It Manager               1
# Oil And Gas              1
# Physician                1
# Planning Engineer        1
# Product Manager          1
# Profession               1
# Program Manager          1
# Programmer               1
# Senior Product Manager   1
# Software Developer       1
# Software Engineer        4
# Student                  1
# Student/Free-Lancer      1
# Teacher                  1
# Technical Analyst        1
# Web Projects Manager     1
# Working                  1

# %%
for txt in df['Q19']:
    print(txt)
# Out:
# nan
# nan
# I do like the idea of automation when it comes to this kind of scheduling instead of searching all around. I don't find that task particularly difficult however but would that option.
# nan
# nan
# nan
# nan
# nan
# No
# nan
# nan
# nan
# nan
# Great idea to implement.
# nan
# This is 100 times easier to use.
# nan
# nan
# nan
# Good job!
# nan
# nan
# nan
# nan
# nan
# Comments
